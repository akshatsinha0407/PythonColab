# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatsinha0407/PythonColab/blob/main/nlp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk

# Download required tokenizer models
nltk.download('punkt')
nltk.download('punkt_tab')

paragraph = """
Virat Kohli (Hindi pronunciation: [ʋɪˈɾaːʈᵊ ˈkoːɦᵊliː] ⓘ, born 5 November 1988) is an Indian international cricketer and
the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-pace bowler.
He currently represents Royal Challengers Bengaluru in the IPL and Delhi in domestic cricket. Kohli is widely regarded as
one of the greatest all-format batters of all time. He also holds the record for scoring the most centuries in ODI cricket
and stands second in the list of most international centuries scored, and is highest run-scorer in the IPL. Kohli was a
member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, 2024 T20 World Cup and 2025
Champions Trophy. Under his captaincy India held the ICC World Test Championship Mace between 2016 and 2020, winning the
end of season prize on three occasions.

In 2013, Kohli was ranked number one in the ICC rankings for ODI batsmen. In 2015, he achieved the summit of T20I rankings.
In 2018, the ICC ranked him as the number one test batsman worldwide under the same ICC rankings. In 2020, the International
Cricket Council named him the male cricketer of the decade.
"""

sentences = nltk.sent_tokenize(paragraph)
print(sentences)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
print(sentences)
# Out:
# ['\nVirat Kohli (Hindi pronunciation: [ʋɪˈɾaːʈᵊ ˈkoːɦᵊliː] ⓘ, born 5 November 1988) is an Indian international cricketer and\nthe former captain of the Indian national cricket team.', 'He is a right-handed batsman and an occasional medium-pace bowler.', 'He currently represents Royal Challengers Bengaluru in the IPL and Delhi in domestic cricket.', 'Kohli is widely regarded as\none of the greatest all-format batters of all time.', 'He also holds the record for scoring the most centuries in ODI cricket\nand stands second in the list of most international centuries scored, and is highest run-scorer in the IPL.', 'Kohli was a\nmember of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, 2024 T20 World Cup and 2025\nChampions Trophy.', 'Under his captaincy India held the ICC World Test Championship Mace between 2016 and 2020, winning the\nend of season prize on three occasions.', 'In 2013, Kohli was ranked number one in the ICC rankings for ODI batsmen.', 'In
# ...

# %%
type(sentences)
# Out:
# list

# %%
stemmer = PorterStemmer()
stemmer.stem('cricketer')
# Out:
# 'cricket'

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Download required data
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize('cricketer'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# cricketer

# %%
import re

corpus = []

for i in range(len(sentences)):
    # Remove everything except letters and spaces
    reviu = re.sub('[^a-zA-Z ]', '', sentences[i])

    # Convert to lowercase
    reviu = reviu.lower()

    # Split into words
    reviu = reviu.split()

    # Append cleaned sentence
    corpus.append(reviu)

# %%
corpus
# Out:
# [['virat',
#   'kohli',
#   'hindi',
#   'pronunciation',
#   'a',
#   'koli',
#   'born',
#   'november',
#   'is',
#   'an',
#   'indian',
#   'international',
#   'cricketer',
#   'andthe',
#   'former',
#   'captain',
#   'of',
#   'the',
#   'indian',
#   'national',
#   'cricket',
#   'team'],
#  ['he',
#   'is',
#   'a',
#   'righthanded',
#   'batsman',
#   'and',
#   'an',
#   'occasional',
#   'mediumpace',
#   'bowler'],
#  ['he',
#   'currently',
#   'represents',
#   'royal',
#   'challengers',
#   'bengaluru',
#   'in',
#   'the',
#   'ipl',
#   'and',
#   'delhi',
#   'in',
#   'domestic',
#   'cricket'],
#  ['kohli',
#   'is',
#   'widely',
#   'regarded',
#   'asone',
#   'of',
#   'the',
#   'greatest',
#   'allformat',
#   'batters',
#   'of',
#   'all',
#   'time'],
#  ['he',
#   'also',
#   'holds',
#   'the',
#   'record',
#   'for',
#   'scoring',
#   'the',
#   'most',
#   'centuries',
#   'in',
#   'odi',
#   'cricketand',
#   'stands',
#   'second',
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')

stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

# corpus is a list of lists
for sentence in corpus:
    for word in sentence:
        if word not in stop_words:
            print(stemmer.stem(word))
# Out:
# virat
# kohli
# hindi
# pronunci
# koli
# born
# novemb
# indian
# intern
# cricket
# andth
# former
# captain
# indian
# nation
# cricket
# team
# righthand
# batsman
# occasion
# mediumpac
# bowler
# current
# repres
# royal
# challeng
# bengaluru
# ipl
# delhi
# domest
# cricket
# kohli
# wide
# regard
# ason
# greatest
# allformat
# batter
# time
# also
# hold
# record
# score
# centuri
# odi
# cricketand
# stand
# second
# list
# intern
# centuri
# score
# highest
# runscor
# ipl
# kohli
# amemb
# indian
# team
# cricket
# world
# cup
# icc
# champion
# trophi
# world
# cup
# champion
# trophi
# captainci
# india
# held
# icc
# world
# test
# championship
# mace
# win
# theend
# season
# prize
# three
# occas
# kohli
# rank
# number
# one
# icc
# rank
# odi
# batsmen
# achiev
# summit
# ti
# rank
# icc
# rank
# number
# one
# test
# batsman
# worldwid
# icc
# rank
# internationalcricket
# council
# name
# male
# cricket
# decad
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Suppose corpus is a list of strings (sentences)
# Agar tumhara corpus abhi list of list hai, use join karke string me convert karo
corpus_strings = [' '.join(sentence) for sentence in corpus]

cv = CountVectorizer()
cv.fit(corpus_strings)

# Vocabulary
print(cv.vocabulary_)
# Out:
# {'virat': 94, 'kohli': 50, 'hindi': 39, 'pronunciation': 68, 'koli': 51, 'born': 15, 'november': 59, 'is': 49, 'an': 5, 'indian': 45, 'international': 46, 'cricketer': 26, 'andthe': 7, 'former': 33, 'captain': 17, 'of': 64, 'the': 87, 'national': 58, 'cricket': 24, 'team': 84, 'he': 35, 'righthanded': 74, 'batsman': 10, 'and': 6, 'occasional': 61, 'mediumpace': 55, 'bowler': 16, 'currently': 28, 'represents': 73, 'royal': 75, 'challengers': 20, 'bengaluru': 13, 'in': 43, 'ipl': 48, 'delhi': 30, 'domestic': 31, 'widely': 96, 'regarded': 72, 'asone': 9, 'greatest': 34, 'allformat': 2, 'batters': 12, 'all': 1, 'time': 91, 'also': 3, 'holds': 41, 'record': 71, 'for': 32, 'scoring': 79, 'most': 56, 'centuries': 19, 'odi': 63, 'cricketand': 25, 'stands': 82, 'second': 81, 'list': 52, 'scored': 78, 'highest': 37, 'runscorer': 76, 'was': 95, 'amember': 4, 'that': 86, 'won': 98, 'world': 99, 'cup': 27, 'icc': 42, 'champions': 21, 'trophy': 92, 'under': 93, 'his': 40, 'captaincy': 18, 'india':
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Convert list of words per sentence into strings
corpus_strings = [' '.join(sentence) for sentence in corpus]

cv = CountVectorizer()
X = cv.fit_transform(corpus_strings)

print("Shape of X:", X.shape)        # Rows = sentences, Columns = unique words
print("Vocabulary:", cv.vocabulary_) # Dictionary of word:index
# Out:
# Shape of X: (11, 101)
# ...

# %% [markdown]
# Lamitization

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Example paragraph
paragraph = """
Virat Kohli (Hindi pronunciation: [ʋɪˈɾaːʈᵊ ˈkoːɦᵊliː] ⓘ, born 5 November 1988) is an Indian international cricketer and
the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-pace bowler.
He currently represents Royal Challengers Bengaluru in the IPL and Delhi in domestic cricket. Kohli is widely regarded as
one of the greatest all-format batters of all time. He also holds the record for scoring the most centuries in ODI cricket
and stands second in the list of most international centuries scored, and is highest run-scorer in the IPL. Kohli was a
member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, 2024 T20 World Cup and 2025
Champions Trophy. Under his captaincy India held the ICC World Test Championship Mace between 2016 and 2020, winning the
end of season prize on three occasions.
In 2013, Kohli was ranked number one in the ICC rankings for ODI batsmen. In 2015, he achieved the summit of T20I rankings.
In 2018, the ICC ranked him as the number one test batsman worldwide under the same ICC rankings. In 2020, the International
Cricket Council named him the male cricketer of the decade.
"""

# Step 1: Sentence tokenization
sentences = nltk.sent_tokenize(paragraph)

# Step 2: Preprocessing + Lemmatization
corpus = []
for sentence in sentences:
    # Remove punctuation and numbers
    sentence = re.sub('[^a-zA-Z ]', '', sentence)
    sentence = sentence.lower()            # lowercase
    words = sentence.split()              # tokenize
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # remove stopwords + lemmatize
    corpus.append(words)

# Step 3: Output
for i, sent in enumerate(corpus):
    print(f"Sentence {i+1}: {sent}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# Sentence 1: ['virat', 'kohli', 'hindi', 'pronunciation', 'koli', 'born', 'november', 'indian', 'international', 'cricketer', 'andthe', 'former', 'captain', 'indian', 'national', 'cricket', 'team']
# Sentence 2: ['righthanded', 'batsman', 'occasional', 'mediumpace', 'bowler']
# Sentence 3: ['currently', 'represents', 'royal', 'challenger', 'bengaluru', 'ipl', 'delhi', 'domestic', 'cricket']
# Sentence 4: ['kohli', 'widely', 'regarded', 'asone', 'greatest', 'allformat', 'batter', 'time']
# Sentence 5: ['also', 'hold', 'record', 'scoring', 'century', 'odi', 'cricketand', 'stand', 'second', 'list', 'international', 'century', 'scored', 'highest', 'runscorer', 'ipl']
# Sentence 6: ['kohli', 'amember', 'indian', 'team', 'cricket', 'world', 'cup', 'icc', 'champion', 'trophy', 'world', 'cup', 'champion', 'trophy']
# ...

# %%
# !pip install scikit-learn

# %%
#TFIDF
corpus = [
    "I love coding in Python",
    "Machine learning is awesome",
    "Python is great for data science"
]

from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()
X = cv.fit_transform(corpus)

# %%
corpus[0]
# Out:
# 'I love coding in Python'

# %%
X[0].toarray()
# Out:
# array([[0.        , 0.52863461, 0.        , 0.        , 0.        ,
#         0.52863461, 0.        , 0.        , 0.52863461, 0.        ,
#         0.40204024, 0.        ]])
