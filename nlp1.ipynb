# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatsinha0407/PythonColab/blob/main/nlp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
import nltk

# Download required tokenizer models
nltk.download('punkt')
nltk.download('punkt_tab')

paragraph = """
Virat Kohli (Hindi pronunciation: [ʋɪˈɾaːʈᵊ ˈkoːɦᵊliː] ⓘ, born 5 November 1988) is an Indian international cricketer and
the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-pace bowler.
He currently represents Royal Challengers Bengaluru in the IPL and Delhi in domestic cricket. Kohli is widely regarded as
one of the greatest all-format batters of all time. He also holds the record for scoring the most centuries in ODI cricket
and stands second in the list of most international centuries scored, and is highest run-scorer in the IPL. Kohli was a
member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, 2024 T20 World Cup and 2025
Champions Trophy. Under his captaincy India held the ICC World Test Championship Mace between 2016 and 2020, winning the
end of season prize on three occasions.

In 2013, Kohli was ranked number one in the ICC rankings for ODI batsmen. In 2015, he achieved the summit of T20I rankings.
In 2018, the ICC ranked him as the number one test batsman worldwide under the same ICC rankings. In 2020, the International
Cricket Council named him the male cricketer of the decade.
"""

sentences = nltk.sent_tokenize(paragraph)
print(sentences)
# Out:
# ['\nVirat Kohli (Hindi pronunciation: [ʋɪˈɾaːʈᵊ ˈkoːɦᵊliː] ⓘ, born 5 November 1988) is an Indian international cricketer and \nthe former captain of the Indian national cricket team.', 'He is a right-handed batsman and an occasional medium-pace bowler.', 'He currently represents Royal Challengers Bengaluru in the IPL and Delhi in domestic cricket.', 'Kohli is widely regarded as \none of the greatest all-format batters of all time.', 'He also holds the record for scoring the most centuries in ODI cricket \nand stands second in the list of most international centuries scored, and is highest run-scorer in the IPL.', 'Kohli was a \nmember of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, 2024 T20 World Cup and 2025 \nChampions Trophy.', 'Under his captaincy India held the ICC World Test Championship Mace between 2016 and 2020, winning the \nend of season prize on three occasions.', 'In 2013, Kohli was ranked number one in the ICC rankings for ODI batsmen.', 'In 2015, he achieved the summit of T20I rankings.', 'In 2018, the ICC ranked him as the number one test batsman worldwide under the same ICC rankings.', 'In 2020, the International \nCricket Council named him the male cricketer of the decade.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
print(sentences)
# Out:
# ['\nVirat Kohli (Hindi pronunciation: [ʋɪˈɾaːʈᵊ ˈkoːɦᵊliː] ⓘ, born 5 November 1988) is an Indian international cricketer and \nthe former captain of the Indian national cricket team.', 'He is a right-handed batsman and an occasional medium-pace bowler.', 'He currently represents Royal Challengers Bengaluru in the IPL and Delhi in domestic cricket.', 'Kohli is widely regarded as \none of the greatest all-format batters of all time.', 'He also holds the record for scoring the most centuries in ODI cricket \nand stands second in the list of most international centuries scored, and is highest run-scorer in the IPL.', 'Kohli was a \nmember of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, 2024 T20 World Cup and 2025 \nChampions Trophy.', 'Under his captaincy India held the ICC World Test Championship Mace between 2016 and 2020, winning the \nend of season prize on three occasions.', 'In 2013, Kohli was ranked number one in the ICC rankings for ODI batsmen.', 'In 2015, he achieved the summit of T20I rankings.', 'In 2018, the ICC ranked him as the number one test batsman worldwide under the same ICC rankings.', 'In 2020, the International \nCricket Council named him the male cricketer of the decade.']

# %%
type(sentences)
# Out:
# list

# %%
stemmer = PorterStemmer()
stemmer.stem('cricketer')
# Out:
# 'cricket'

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Download required data
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize('cricketer'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# cricketer

# %%
import re

corpus = []

for i in range(len(sentences)):
    # Remove everything except letters and spaces
    reviu = re.sub('[^a-zA-Z ]', '', sentences[i])

    # Convert to lowercase
    reviu = reviu.lower()

    # Split into words
    reviu = reviu.split()

    # Append cleaned sentence
    corpus.append(reviu)

# %%
corpus
# Out:
# [['virat',
#   'kohli',
#   'hindi',
#   'pronunciation',
#   'a',
#   'koli',
#   'born',
#   'november',
#   'is',
#   'an',
#   'indian',
#   'international',
#   'cricketer',
#   'and',
#   'the',
#   'former',
#   'captain',
#   'of',
#   'the',
#   'indian',
#   'national',
#   'cricket',
#   'team'],
#  ['he',
#   'is',
#   'a',
#   'righthanded',
#   'batsman',
#   'and',
#   'an',
#   'occasional',
#   'mediumpace',
#   'bowler'],
#  ['he',
#   'currently',
#   'represents',
#   'royal',
#   'challengers',
#   'bengaluru',
#   'in',
#   'the',
#   'ipl',
#   'and',
#   'delhi',
#   'in',
#   'domestic',
#   'cricket'],
#  ['kohli',
#   'is',
#   'widely',
#   'regarded',
#   'as',
#   'one',
#   'of',
#   'the',
#   'greatest',
#   'allformat',
#   'batters',
#   'of',
#   'all',
#   'time'],
#  ['he',
#   'also',
#   'holds',
#   'the',
#   'record',
#   'for',
#   'scoring',
#   'the',
#   'most',
#   'centuries',
#   'in',
#   'odi',
#   'cricket',
#   'and',
#   'stands',
#   'second',
#   'in',
#   'the',
#   'list',
#   'of',
#   'most',
#   'international',
#   'centuries',
#   'scored',
#   'and',
#   'is',
#   'highest',
#   'runscorer',
#   'in',
#   'the',
#   'ipl'],
#  ['kohli',
#   'was',
#   'a',
#   'member',
#   'of',
#   'the',
#   'indian',
#   'team',
#   'that',
#   'won',
#   'the',
#   'cricket',
#   'world',
#   'cup',
#   'icc',
#   'champions',
#   'trophy',
#   't',
#   'world',
#   'cup',
#   'and',
#   'champions',
#   'trophy'],
#  ['under',
#   'his',
#   'captaincy',
#   'india',
#   'held',
#   'the',
#   'icc',
#   'world',
#   'test',
#   'championship',
#   'mace',
#   'between',
#   'and',
#   'winning',
#   'the',
#   'end',
#   'of',
#   'season',
#   'prize',
#   'on',
#   'three',
#   'occasions'],
#  ['in',
#   'kohli',
#   'was',
#   'ranked',
#   'number',
#   'one',
#   'in',
#   'the',
#   'icc',
#   'rankings',
#   'for',
#   'odi',
#   'batsmen'],
#  ['in', 'he', 'achieved', 'the', 'summit', 'of', 'ti', 'rankings'],
#  ['in',
#   'the',
#   'icc',
#   'ranked',
#   'him',
#   'as',
#   'the',
#   'number',
#   'one',
#   'test',
#   'batsman',
#   'worldwide',
#   'under',
#   'the',
#   'same',
#   'icc',
#   'rankings'],
#  ['in',
#   'the',
#   'international',
#   'cricket',
#   'council',
#   'named',
#   'him',
#   'the',
#   'male',
#   'cricketer',
#   'of',
#   'the',
#   'decade']]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')

stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

# corpus is a list of lists
for sentence in corpus:
    for word in sentence:
        if word not in stop_words:
            print(stemmer.stem(word))
# Out:
# virat
# kohli
# hindi
# pronunci
# koli
# born
# novemb
# indian
# intern
# cricket
# former
# captain
# indian
# nation
# cricket
# team
# righthand
# batsman
# occasion
# mediumpac
# bowler
# current
# repres
# royal
# challeng
# bengaluru
# ipl
# delhi
# domest
# cricket
# kohli
# wide
# regard
# one
# greatest
# allformat
# batter
# time
# also
# hold
# record
# score
# centuri
# odi
# cricket
# stand
# second
# list
# intern
# centuri
# score
# highest
# runscor
# ipl
# kohli
# member
# indian
# team
# cricket
# world
# cup
# icc
# champion
# trophi
# world
# cup
# champion
# trophi
# captainci
# india
# held
# icc
# world
# test
# championship
# mace
# win
# end
# season
# prize
# three
# occas
# kohli
# rank
# number
# one
# icc
# rank
# odi
# batsmen
# achiev
# summit
# ti
# rank
# icc
# rank
# number
# one
# test
# batsman
# worldwid
# icc
# rank
# intern
# cricket
# council
# name
# male
# cricket
# decad
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Suppose corpus is a list of strings (sentences)
# Agar tumhara corpus abhi list of list hai, use join karke string me convert karo
corpus_strings = [' '.join(sentence) for sentence in corpus]

cv = CountVectorizer()
cv.fit(corpus_strings)

# Vocabulary
print(cv.vocabulary_)
# Out:
# {'virat': 90, 'kohli': 46, 'hindi': 36, 'pronunciation': 65, 'koli': 47, 'born': 12, 'november': 56, 'is': 45, 'an': 4, 'indian': 42, 'international': 43, 'cricketer': 22, 'and': 5, 'the': 84, 'former': 30, 'captain': 14, 'of': 61, 'national': 55, 'cricket': 21, 'team': 81, 'he': 32, 'righthanded': 71, 'batsman': 7, 'occasional': 58, 'mediumpace': 51, 'bowler': 13, 'currently': 24, 'represents': 70, 'royal': 72, 'challengers': 17, 'bengaluru': 10, 'in': 40, 'ipl': 44, 'delhi': 26, 'domestic': 27, 'widely': 92, 'regarded': 69, 'as': 6, 'one': 63, 'greatest': 31, 'allformat': 2, 'batters': 9, 'all': 1, 'time': 87, 'also': 3, 'holds': 38, 'record': 68, 'for': 29, 'scoring': 76, 'most': 53, 'centuries': 16, 'odi': 60, 'stands': 79, 'second': 78, 'list': 48, 'scored': 75, 'highest': 34, 'runscorer': 73, 'was': 91, 'member': 52, 'that': 83, 'won': 94, 'world': 95, 'cup': 23, 'icc': 39, 'champions': 18, 'trophy': 88, 'under': 89, 'his': 37, 'captaincy': 15, 'india': 41, 'held': 33, 'test': 82, 'championship': 19, 'mace': 49, 'between': 11, 'winning': 93, 'end': 28, 'season': 77, 'prize': 64, 'on': 62, 'three': 85, 'occasions': 59, 'ranked': 66, 'number': 57, 'rankings': 67, 'batsmen': 8, 'achieved': 0, 'summit': 80, 'ti': 86, 'him': 35, 'worldwide': 96, 'same': 74, 'council': 20, 'named': 54, 'male': 50, 'decade': 25}

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Convert list of words per sentence into strings
corpus_strings = [' '.join(sentence) for sentence in corpus]

cv = CountVectorizer()
X = cv.fit_transform(corpus_strings)

print("Shape of X:", X.shape)        # Rows = sentences, Columns = unique words
print("Vocabulary:", cv.vocabulary_) # Dictionary of word:index
# Out:
# Shape of X: (11, 97)
# Vocabulary: {'virat': 90, 'kohli': 46, 'hindi': 36, 'pronunciation': 65, 'koli': 47, 'born': 12, 'november': 56, 'is': 45, 'an': 4, 'indian': 42, 'international': 43, 'cricketer': 22, 'and': 5, 'the': 84, 'former': 30, 'captain': 14, 'of': 61, 'national': 55, 'cricket': 21, 'team': 81, 'he': 32, 'righthanded': 71, 'batsman': 7, 'occasional': 58, 'mediumpace': 51, 'bowler': 13, 'currently': 24, 'represents': 70, 'royal': 72, 'challengers': 17, 'bengaluru': 10, 'in': 40, 'ipl': 44, 'delhi': 26, 'domestic': 27, 'widely': 92, 'regarded': 69, 'as': 6, 'one': 63, 'greatest': 31, 'allformat': 2, 'batters': 9, 'all': 1, 'time': 87, 'also': 3, 'holds': 38, 'record': 68, 'for': 29, 'scoring': 76, 'most': 53, 'centuries': 16, 'odi': 60, 'stands': 79, 'second': 78, 'list': 48, 'scored': 75, 'highest': 34, 'runscorer': 73, 'was': 91, 'member': 52, 'that': 83, 'won': 94, 'world': 95, 'cup': 23, 'icc': 39, 'champions': 18, 'trophy': 88, 'under': 89, 'his': 37, 'captaincy': 15, 'india': 41, 'held': 33, 'test': 82, 'championship': 19, 'mace': 49, 'between': 11, 'winning': 93, 'end': 28, 'season': 77, 'prize': 64, 'on': 62, 'three': 85, 'occasions': 59, 'ranked': 66, 'number': 57, 'rankings': 67, 'batsmen': 8, 'achieved': 0, 'summit': 80, 'ti': 86, 'him': 35, 'worldwide': 96, 'same': 74, 'council': 20, 'named': 54, 'male': 50, 'decade': 25}

# %% [markdown]
# Lamitization

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Example paragraph
paragraph = """
Virat Kohli (Hindi pronunciation: [ʋɪˈɾaːʈᵊ ˈkoːɦᵊliː] ⓘ, born 5 November 1988) is an Indian international cricketer and
the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-pace bowler.
He currently represents Royal Challengers Bengaluru in the IPL and Delhi in domestic cricket. Kohli is widely regarded as
one of the greatest all-format batters of all time. He also holds the record for scoring the most centuries in ODI cricket
and stands second in the list of most international centuries scored, and is highest run-scorer in the IPL. Kohli was a
member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, 2024 T20 World Cup and 2025
Champions Trophy. Under his captaincy India held the ICC World Test Championship Mace between 2016 and 2020, winning the
end of season prize on three occasions.
In 2013, Kohli was ranked number one in the ICC rankings for ODI batsmen. In 2015, he achieved the summit of T20I rankings.
In 2018, the ICC ranked him as the number one test batsman worldwide under the same ICC rankings. In 2020, the International
Cricket Council named him the male cricketer of the decade.
"""

# Step 1: Sentence tokenization
sentences = nltk.sent_tokenize(paragraph)

# Step 2: Preprocessing + Lemmatization
corpus = []
for sentence in sentences:
    # Remove punctuation and numbers
    sentence = re.sub('[^a-zA-Z ]', '', sentence)
    sentence = sentence.lower()            # lowercase
    words = sentence.split()              # tokenize
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # remove stopwords + lemmatize
    corpus.append(words)

# Step 3: Output
for i, sent in enumerate(corpus):
    print(f"Sentence {i+1}: {sent}")
# Out:
# Sentence 1: ['virat', 'kohli', 'hindi', 'pronunciation', 'koli', 'born', 'november', 'indian', 'international', 'cricketer', 'former', 'captain', 'indian', 'national', 'cricket', 'team']
# Sentence 2: ['righthanded', 'batsman', 'occasional', 'mediumpace', 'bowler']
# Sentence 3: ['currently', 'represents', 'royal', 'challenger', 'bengaluru', 'ipl', 'delhi', 'domestic', 'cricket']
# Sentence 4: ['kohli', 'widely', 'regarded', 'one', 'greatest', 'allformat', 'batter', 'time']
# Sentence 5: ['also', 'hold', 'record', 'scoring', 'century', 'odi', 'cricket', 'stand', 'second', 'list', 'international', 'century', 'scored', 'highest', 'runscorer', 'ipl']
# Sentence 6: ['kohli', 'member', 'indian', 'team', 'cricket', 'world', 'cup', 'icc', 'champion', 'trophy', 'world', 'cup', 'champion', 'trophy']
# Sentence 7: ['captaincy', 'india', 'held', 'icc', 'world', 'test', 'championship', 'mace', 'winning', 'end', 'season', 'prize', 'three', 'occasion']
# Sentence 8: ['kohli', 'ranked', 'number', 'one', 'icc', 'ranking', 'odi', 'batsman']
# Sentence 9: ['achieved', 'summit', 'ti', 'ranking']
# Sentence 10: ['icc', 'ranked', 'number', 'one', 'test', 'batsman', 'worldwide', 'icc', 'ranking']
# Sentence 11: ['international', 'cricket', 'council', 'named', 'male', 'cricketer', 'decade']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
